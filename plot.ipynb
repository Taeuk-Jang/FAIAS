# %%
import numpy as np
from plot import plot

# %%
# name = 'res'
name = 'vgg16'
path = 'save_compare_data/'
dataset = 'celeba'
dataset_used = 'celeba'

total_acc = np.load(path + name + '_total_acc.npz')['total_acc']
total_balanced_acc = np.load(path + name + '_total_balanced_acc.npz')['total_balanced_acc']
total_disimpact = np.load(path + name + '_total_disimpact.npz')['total_disimpact']
total_eqopp_diff = np.load(path + name + '_total_eqopp_diff.npz')['total_eqopp_diff']
total_aveodds_diff = np.load(path + name + '_total_aveodds_diff.npz')['total_aveodds_diff']
total_theil_idx = np.load(path + name + '_total_theil_idx.npz')['total_theil_idx']
stat_parity_diff = np.load(path + name + '_stat_parity_diff.npz')['stat_parity_diff']
total_tpr = np.load(path + name + '_total_tpr.npz')['total_tpr']
total_fpr_diff = np.load(path + name + '_total_fpr_diff.npz')['total_fpr_diff']
total_aveodds_diff = 0.5 * (abs(total_fpr_diff) + abs(total_eqopp_diff))
name +='_sex'
# name = 'res50' + '_sex'

laftr_dir= '/home/taeuk/network/git/laftr/experiments/result/{}/'.format(dataset + '_' + name)

total_acc[8, :] = np.load(laftr_dir + 'laftr_ACC.npy')[1:4]
total_tpr[8, :] = np.load(laftr_dir + 'laftr_A=?_TPR.npy')[1:4]
total_eqopp_diff[8, :] = np.load(laftr_dir + 'laftr_Eq_Opp_diff.npy')[1:4]
total_aveodds_diff[8, :] = np.load(laftr_dir + 'laftr_Av_abs_odd_diff.npy')[1:4]
total_disimpact[8, :] = np.load(laftr_dir + 'laftr_DISP.npy')[1:4]

name = name.split('_')[0]

# %%
setting = 'best/' + dataset + '/' + name
dataset_used = 'celeba_'+name
plot(total_acc, 0, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
# plot(total_balanced_acc, 1, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
plot(np.abs(1-total_disimpact), 2, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
plot(np.abs(total_eqopp_diff), 3, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
plot(np.abs(total_aveodds_diff), 4, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
# plot(np.abs(total_theil_idx), 5, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
# plot(np.abs(stat_parity_diff), 6, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
plot(np.abs(total_tpr), 7, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
# plot(np.abs(total_fpr_diff), 8, dataset_used, setting, method_idx = [10,1,2,3,6,8,9], show = True, save = True)
